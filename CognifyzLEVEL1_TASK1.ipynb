# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarinibo/Cognifyz-project-/blob/main/CognifyzLEVEL1_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *LEVEL* ONE : **Task** **1**
#
# **Task**: Data exploration and preprocessing
# - [ ] Explore the dataset and identify the number of rows and columns
# - [ ] Check for the missing values in each column and handle them accordingly
# - [ ] Perform data type conversion if necessary. Analyze the distribution of the target variable (“Aggregate rating “) and identify any class imbalances

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/Othercomputers/My Laptop/Desktop/Dataset.csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# - [ ] Explore the dataset and identify the number of rows and columns

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# - [ ] Check for the missing values in each column and handle them accordingly

# %%
df.fillna({'Cuisines': 'unknown'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# - [ ] Perform data type conversion if necessary. Analyze the distribution of the target variable (“Aggregate rating “) and identify any class imbalances

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df['Aggregate rating']. value_counts()
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
# 2. Define bins for the numeric "Aggregate rating" column
#    Adjust these bin edges to suit your dataset
bins = [0, 1, 2, 3, 4, 5]  # Ratings can be from 0.0 to 5.0
labels = ["0-1", "1-2", "2-3", "3-4", "4-5"]

# 3. Convert "Aggregate rating" into a categorical variable by binning
df["rating_bin"] = pd.cut(df["Aggregate rating"], bins=bins, labels=labels, right=False)

# 4. Calculate the distribution
class_counts = df["rating_bin"].value_counts().sort_index()
class_percentages = (class_counts / class_counts.sum()) * 100

# 5. Print the counts and percentages
print("Class Counts:\n", class_counts)
print("\nClass Distribution (%):\n", class_percentages)

# 6. Visualize the distribution
plt.figure(figsize=(8, 5))
class_counts.plot(kind="bar", color="skyblue")
plt.xlabel("Binned Aggregate Rating")
plt.ylabel("Count")
plt.title("Class Distribution (Binned Aggregate Rating)")
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
# Out:
# Class Counts:
#  rating_bin
# 0-1    2148
# 1-2       3
# 2-3    1430
# 3-4    4590
# 4-5    1380
# Name: count, dtype: int64
#
# Class Distribution (%):
#  rating_bin
# 0-1    22.489792
# 1-2     0.031410
# 2-3    14.972254
# 3-4    48.057795
# 4-5    14.448749
# Name: count, dtype: float64

# %% [markdown]
# ## Handling class imbalance in the distribution

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

# ... (your previous code for data loading and preprocessing) ...

# Identify categorical columns
cat_cols = X.select_dtypes(include=['object']).columns

# Apply Label Encoding
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le  # Save encoder for future use

# Adjust 'k_neighbors' parameter in SMOTE
# The error occurs when a class has fewer samples than k_neighbors.
# Check the class distribution to identify the smallest class size.
# Assuming 'y' is your target variable
min_class_size = y.value_counts().min()

# Set k_neighbors to be less than the smallest class size
smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=min(5, min_class_size - 1))
# min is to limit up to 5, max is one less than the data sample size

X_resampled, y_resampled = smote.fit_resample(X, y)

df_balanced = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='Rating Category')], axis=1)

# %%
# Convert to DataFrame for proper ordering
y_df = pd.DataFrame({'Rating Category': y.value_counts().index, 'Count': y.value_counts().values})
y_resampled_df = pd.DataFrame({'Rating Category': y_resampled.value_counts().index, 'Count': y_resampled.value_counts().values})

# Plot before SMOTE
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.barplot(data=y_df, x="Rating Category", y="Count", hue="Rating Category", legend=False, palette="coolwarm")
plt.title("Class Distribution Before SMOTE")
plt.xlabel("Rating Category")
plt.ylabel("Count")
plt.xticks(rotation=90)

# Plot after SMOTE
plt.subplot(1, 2, 2)
sns.barplot(data=y_resampled_df, x="Rating Category", y="Count", hue="Rating Category", legend=False, palette="coolwarm")
plt.title("Class Distribution After SMOTE")
plt.xlabel("Rating Category")
plt.ylabel("Count")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
